# %%
pip install langchain-openai
# Out:
# ...
#   Obtaining dependency information for langchain-openai from https://files.pythonhosted.org/packages/e6/3d/e22ee65fff79afe7bdfbd67844243eb279b440c882dad9e4262dcc87131f/langchain_openai-0.3.32-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for langchain-core<1.0.0,>=0.3.74 from https://files.pythonhosted.org/packages/fb/42/0d0221cce6f168f644d7d96cb6c87c4e42fc55d2941da7a36e970e3ab8ab/langchain_core-0.3.75-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for openai<2.0.0,>=1.99.9 from https://files.pythonhosted.org/packages/bd/0d/c9e7016d82c53c5b5e23e2bad36daebb8921ed44f69c0a985c6529a35106/openai-1.102.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tiktoken<1,>=0.7 from https://files.pythonhosted.org/packages/60/d9/884b6cd7ae2570ecdcaffa02b528522b18fef1cbbfdbcaa73799807d0d3b/tiktoken-0.11.0-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
pip install --upgrade pydantic openai langchain langchain-openai
# Out:
# ...
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/f6/d5/4861816a95b2f6993f1360cfb605aacb015506ee2090433a71de9cca8477/langchain-0.3.27-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for langchain-text-splitters<1.0.0,>=0.3.9 from https://files.pythonhosted.org/packages/4c/dc/d64c9990f6aeb209e8d47b34ebaa2b787f3e4c10c99b8a5568a10beda449/langchain_text_splitters-0.3.10-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for SQLAlchemy<3,>=1.4 from https://files.pythonhosted.org/packages/ee/13/744a32ebe3b4a7a9c7ea4e57babae7aa22070d47acf330d8e5a1359607f1/sqlalchemy-2.0.43-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pip>=25.2 from https://files.pythonhosted.org/packages/b7/3f/945ef7ab14dc4f9d7f40288d2df998d1837ee0888ec3659c813487572faa/pip-25.2-py3-none-any.whl.metadata
# ...

# %%
pip install dotenv
# Out:
# ...
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# ...
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# ...
#
#    ---------------------------------------- 0/2 [python-dotenv]
#    ---------------------------------------- 0/2 [python-dotenv]
#    ---------------------------------------- 0/2 [python-dotenv]
#    ---------------------------------------- 0/2 [python-dotenv]
#    -------------------- ------------------- 1/2 [dotenv]
#    ---------------------------------------- 2/2 [dotenv]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(r"C:\Users\RUN\Documents\.env")
# Out:
# True

# %%
# to see all available models (There are paid ones out there!!)
from langchain_openai import ChatOpenAI
from openai import OpenAI

client = OpenAI()
models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# gpt-3.5-turbo
# gpt-audio
# gpt-5-mini
# gpt-5-nano-2025-08-07
# gpt-5-nano
# gpt-audio-2025-08-28
# davinci-002
# babbage-002
# gpt-3.5-turbo-instruct
# gpt-3.5-turbo-instruct-0914
# dall-e-3
# dall-e-2
# gpt-3.5-turbo-1106
# tts-1-hd
# tts-1-1106
# tts-1-hd-1106
# text-embedding-3-small
# text-embedding-3-large
# gpt-3.5-turbo-0125
# gpt-4o
# gpt-4o-2024-05-13
# gpt-4o-mini-2024-07-18
# gpt-4o-mini
# gpt-4o-2024-08-06
# o1-mini-2024-09-12
# o1-mini
# gpt-4o-audio-preview-2024-10-01
# gpt-4o-audio-preview
# omni-moderation-latest
# omni-moderation-2024-09-26
# gpt-4o-audio-preview-2024-12-17
# gpt-4o-mini-audio-preview-2024-12-17
# o1-2024-12-17
# o1
# gpt-4o-mini-audio-preview
# o3-mini
# o3-mini-2025-01-31
# gpt-4o-2024-11-20
# gpt-4o-search-preview-2025-03-11
# gpt-4o-search-preview
# gpt-4o-mini-search-preview-2025-03-11
# gpt-4o-mini-search-preview
# gpt-4o-transcribe
# gpt-4o-mini-transcribe
# gpt-4o-mini-tts
# o3-2025-04-16
# o4-mini-2025-04-16
# o3
# o4-mini
# ...

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")
response = llm.invoke("Explain LangChain in a single sentence.")
print(response.content)
# Out:
# LangChain is a framework designed to simplify the development of applications that utilize language models, enabling seamless integration of external data sources and tools for enhanced functionality.

# %%
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)
from langchain_openai import ChatOpenAI

chat = ChatOpenAI(model_name="gpt-4o-mini", temperature=0.3)
messages = [
    SystemMessage(content="You are a mathematics teacher"),
    HumanMessage(content="Teach how to add or subtract multiple digit numbers easily")
]
response = chat.invoke(messages)
print(response.content,end='\n')
# Out:
# Adding and subtracting multiple-digit numbers can be made easier with a few strategies. Here are some methods you can use:
#
# ### 1. **Column Method (Standard Algorithm)**
#
# This is the traditional method where you align the numbers by their place values (units, tens, hundreds, etc.) and perform the addition or subtraction column by column.
#
# **Example: Adding 456 and 789**
#
# ```
#    456
# + 789
# ______
# ```
#
# - Start from the rightmost column (units):
#   - 6 + 9 = 15. Write down 5 and carry over 1.
#
# ```
#    1  (carry)
#    456
# + 789
# ______
#      5
# ```
#
# - Move to the next column (tens):
#   - 5 + 8 + 1 (carry) = 14. Write down 4 and carry over 1.
#
# ```
#    1  (carry)
#    456
# + 789
# ______
#     45
# ```
#
# - Move to the last column (hundreds):
#   - 4 + 7 + 1 (carry) = 12. Write down 2 and carry over 1.
#
# ```
#    1  (carry)
#    456
# + 789
# ______
#   1245
# ```
#
# So, 456 + 789 = 1245.
#
# ### 2. **Break Apart Method (Expanded Form)**
#
# ...
